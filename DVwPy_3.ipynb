# %% [markdown]
# <a href="https://colab.research.google.com/github/bagcakaya/DVwPy-3/blob/main/DVwPy_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Basic Libraries
import pandas as pd
import numpy as np
import scipy
# Libraries for visualizaton
import matplotlib.pyplot as plt
import seaborn as sns
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'exercise', 'flights', 'fmri', 'gammas', 'geyser', 'iris', 'mpg', 'penguins', 'planets', 'taxis', 'tips', 'titanic']

# %%
tips = sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.scatterplot(x="total_bill",
                y="tip",
                data=tips,
                hue="sex")

# %%
langs = ['C', 'C++', 'Java', 'Python', 'PHP']
students = [23,17,35,29,12]
fig, ax = plt.subplots()
ax.bar(langs, students)
for i in range(len(langs)):
    plt.text(langs[i], students[i], str(students[i]), ha="center",va="bottom")

# %%
# with matplotlib
fig, ax = plt.subplots()
x = df.index
y = df.total_bill
ax.bar(x,y )
ax.set_title("Total Bill Distribution by Days")
for i in range(len(x)):
    plt.text(x[i], y[i], str(round(y[i],2)), ha="center",va="bottom")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-05f7444a27c6> in <module>()
#       1 # with matplotlib
#       2 fig, ax = plt.subplots()
# ----> 3 x = df.index
#       4 y = df.total_bill
#       5 ax.bar(x,y )
#
# NameError: name 'df' is not defined

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
ax = sns.scatterplot(x='total_bill',y='tip',data=tips)
ax.set(xlabel='Total Bill', ylabel='Tip', title='Some title')

#plt.legend(labels=['legend1'])
plt.show()

# %%
tips.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3

# %%
sns.scatterplot(x="total_bill", y="tip", data=tips, hue="sex", style="sex")

# %% [markdown]
# # Hue

# %%
sns.scatterplot(x="total_bill", y="tip", data=tips, hue="sex", s=200)

# %% [markdown]
# # Style

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x="total_bill", y="tip", data=tips, hue="sex", s=100, style="sex")

# %%
sns.scatterplot(x="total_bill",y="tip",size="sex", data=tips);

# %%
sns.scatterplot(x="total_bill", y="tip", s=200, data=tips, alpha=0.2)

# %% [markdown]
# # Distributions Plots

# %% [markdown]
# * kdeplot
# * rugplot
# * displot
# * histplot

# %%
#rug plot
sns.rugplot(tips["total_bill"])

# %%
sns.rugplot(x="total_bill", data=tips, height=0.025)

# %%
#displot
sns.displot(x="total_bill", data=tips)

# %%
sns.displot(tips["total_bill"])

# %%
sns.displot(x="total_bill", data=tips, kde=True)

# %%
#histplot
sns.histplot(data = tips, x = "total_bill", bins=30)

# %%
sns.histplot(data = tips, x = "total_bill", bins=30, kde=True)

# %%
sns.set(style="whitegrid")
sns.histplot(data = tips, x = "total_bill", bins=20)

# %% [markdown]
# **Adding in keywords from matplotlib**

# %%
sns.displot(data = tips, x = 'total_bill',bins=20,kde=False,
            color='red',edgecolor='black',lw=4,ls='--')

# %% [markdown]
# **The Kernel Density Estimation Plot**

# %%
sns.kdeplot(x ="total_bill", data=tips);

# %% [markdown]
# **Cut Off KDE**

# %%
sns.kdeplot(x ="total_bill", data=tips, clip=[10,20]);

# %% [markdown]
# **Bandwidth**

# %%
sns.kdeplot(x ="total_bill", data=tips, bw_adjust = 0.1);

# %%
sns.kdeplot(x ="total_bill", data=tips, bw_adjust = 0.2, shade=True, color="red");

# %% [markdown]
# **2 Dimensional KDE Plots**

# %%
data = pd.DataFrame(np.random.normal(0,1,size=(100,2)),columns=['x','y'])
data
# Out:
#            x         y
# 0   0.113032  0.846177
# 1   0.356377 -0.479840
# 2  -0.542210 -0.493805
# 3   1.438437 -0.045418
# 4   0.297875 -0.896573
# ..       ...       ...
# 95 -0.683189 -0.124044
# 96 -1.035811 -1.194639
# 97 -0.403249  1.683105
# 98  0.511300  0.988758
# 99  0.643090  0.600966
#
# [100 rows x 2 columns]

# %%
sns.kdeplot(data = data, x = "x", y = "y");

# %% [markdown]
# # Categorical Plots

# %% [markdown]
# * barplot
# *
# *
# *

# %% [markdown]
# # Comprasion Plots
